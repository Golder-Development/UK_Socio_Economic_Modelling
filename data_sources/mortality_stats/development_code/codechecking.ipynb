# %%
import pandas

# %%
# load data from uk_socio_economic_modelling\data_source\mortality_stats\uk_mortality_by_cause_1901_2000_harmonized.zip 
# into a pandas frame and filter on load to only include rows icd_3

df = pandas.read_csv(r'h:\VScode\UK_Socio_Economic_Modelling\data_sources\mortality_stats\uk_mortality_by_cause_1901_2000_harmonized.zip')
df = df[df['icd_version'] == 3]
